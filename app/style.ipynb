# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
con =  create_engine("postgresql+psycopg2://leitor:leitor123@personal.cxe0iuo8g20s.us-east-1.rds.amazonaws.com:5432/postgres")

# %%
# Set Color Map
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred','lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 
'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']

list_color = []
list_comprehension = [list_color.extend([color]*10) for color in colors]

nums = []
list_comprehension = [nums.extend(np.arange(0,10)) for i in range(len(colors))]

rgb = 

df_color = pd.DataFrame({'color': list_color, 'num_icon':nums})
df_color = df_color.reset_index()

# %%
df_color.merge(
# Out:
#      index      color  num_icon
# 0        0        red         0
# 1        1        red         1
# 2        2        red         2
# 3        3        red         3
# 4        4        red         4
# ..     ...        ...       ...
# 185    185  lightgray         5
# 186    186  lightgray         6
# 187    187  lightgray         7
# 188    188  lightgray         8
# 189    189  lightgray         9
#
# [190 rows x 3 columns]

# %%
df = pd.read_sql('''
select * from hostelworld_hostel hh  where "type" = 'HOSTEL' and country = 'Brazil' and city = 'Florianopolis'
''', con)

# %%
df = df.sort_values(by = 'qtd_rating', ascending = False)
df = df.reset_index()
df = df.merge(df_color[['color','num_icon']], how='left', left_index=True, right_index=True)

# %%
df.rename(columns = {'num_icon':'Marcador'}, inplace = True)

# %%
df_view = df[['color','Marcador','name','qtd_rating','currency','city','country','deposit_percentage','checkin_start','checkin_end','url']].sort_values(by = 'qtd_rating', ascending = False)

# %%
color_mapping = {
    'red': (255, 0, 0, opacidade),
    'blue': (0, 0, 255, opacidade),
    'green': (0, 128, 0, opacidade),
    'purple': (128, 0, 128, opacidade),
    'orange': (255, 165, 0, opacidade),
    'darkred': (139, 0, 0, opacidade),
    'lightred': (255, 99, 71,opacidade),
    'beige': (245, 245, 220, opacidade),
    'darkblue': (0, 0, 139, opacidade),
    'darkgreen': (0, 100, 0, opacidade),
    'cadetblue': (95, 158, 160, opacidade),
    'darkpurple': (128, 0, 128, opacidade),
    'white': (255, 255, 255, opacidade),
    'pink': (255, 192, 203, opacidade),
    'lightblue': (173, 216, 230, opacidade),
    'lightgreen': (144, 238, 144, opacidade),
    'gray': (128, 128, 128, opacidade),
    'black': (0, 0, 0, opacidade),
    'lightgray': (211, 211, 211, opacidade)
}

# %%
def negrito(v):
    return f"font-weight: bold; text_align: center"

# %%
def make_clickable(val):
    return '<a href="{}">Link</a>'.format(val)

# %%
opacidade = 0.1

# %%
def apply_style(row):
    styles = []
    for val in row.index:
        if val not in ('color','Marcador'): 
            styles.append(f'background-color: rgba{color_mapping[row["color"]]};')
        else:
            styles.append(f'background-color: {row["color"]};')
    return styles

# %%
df_view.rename(columns = {
    'name': 'Hostel',
    'city': 'Cidade',
    'country': 'País',
    'qtd_rating':'Avaliações',
    'url': 'URL',
    'currency': 'Moeda',
    'checkin_start': 'Início Check-In',
    'checkin_end': 'Fim Check-In',
    'deposit_percentage':'Adiantamento'
}, inplace = True)

# %%
(
df_view.style
    .map(negrito, subset=['Hostel','Cidade','URL','Marcador','Início Check-In','Fim Check-In'])
    .hide()
    .apply(apply_style, axis=1, subset=['color','Hostel','Marcador','Avaliações'])
    .hide(subset=['color'], axis = 1)
    .set_properties(**{'text-align': 'center'}, subset=pd.IndexSlice[:, ['Marcador','Início Check-In','Fim Check-In']])
    .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])
    .format({'Adiantamento': '{:.0f} %'.format})
    .format({'Início Check-In': lambda x : f'{x:.0f}:00',  'Fim Check-In': lambda x : f'{x:.0f}:00'})
    .format(make_clickable, subset=['URL'])
)
# Out:
# <style type="text/css">
# #T_9e22a th {
#   text-align: center;
# }
# #T_9e22a_row0_col1, #T_9e22a_row1_col1, #T_9e22a_row2_col1, #T_9e22a_row3_col1, #T_9e22a_row4_col1, #T_9e22a_row5_col1, #T_9e22a_row6_col1, #T_9e22a_row7_col1, #T_9e22a_row8_col1, #T_9e22a_row9_col1 {
#   font-weight: bold;
#   text_align: center;
#   background-color: red;
#   text-align: center;
# }
# #T_9e22a_row0_col2, #T_9e22a_row1_col2, #T_9e22a_row2_col2, #T_9e22a_row3_col2, #T_9e22a_row4_col2, #T_9e22a_row5_col2, #T_9e22a_row6_col2, #T_9e22a_row7_col2, #T_9e22a_row8_col2, #T_9e22a_row9_col2 {
#   font-weight: bold;
#   text_align: center;
#   background-color: rgba(255, 0, 0, 0.1);
# }
# #T_9e22a_row0_col3, #T_9e22a_row1_col3, #T_9e22a_row2_col3, #T_9e22a_row3_col3, #T_9e22a_row4_col3, #T_9e22a_row5_col3, #T_9e22a_row6_col3, #T_9e22a_row7_col3, #T_9e22a_row8_col3, #T_9e22a_row9_col3 {
#   background-color: rgba(255, 0, 0, 0.1);
# }
# #T_9e22a_row0_col5, #T_9e22a_row0_col10, #T_9e22a_row1_col5, #T_9e22a_row1_col10, #T_9e22a_row2_col5, #T_9e22a_row2_col10, #T_9e22a_row3_col5, #T_9e22a_row3_col10, #T_9e22a_row4_col5, #T_9e22a_row4_col10, #T_9e22a_row5_col5, #T_9e22a_row5_col10, #T_9e22a_row6_col5, #T_9e22a_row6_col10, #T_9e22a_row7_col5, #T_9e22a_row7_col10, #T_9e22a_row8_col5, #T_9e22a_row8_col10, #T_9e22a_row9_col5, #T_9e22a_row9_col10, #T_9e22a_row10_col5, #T_9e22a_row10_col10, #T_9e22a_row11_col5, #T_9e22a_row11_col10, #T_9e22a_row12_col5, #T_9e22a_row12_col10, #T_9e22a_row13_col5, #T_9e22a_row13_col10, #T_9e22a_row14_col5, #T_9e22a_row14_col10, #T_9e22a_row15_col5, #T_9e22a_row15_col10, #T_9e22a_row16_col5, #T_9e22a_row16_col10, #T_9e22a_row17_col5, #T_9e22a_row17_col10, #T_9e22a_row18_col5, #T_9e22a_row18_col10, #T_9e22a_row19_col5, #T_9e22a_row19_col10, #T_9e22a_row20_col5, #T_9e22a_row20_col10, #T_9e22a_row21_col5, #T_9e22a_row21_col10, #T_9e22a_row22_col5, #T_9e22a_row22_col10, #T_9e22a_row23_col5, #T_9e22a_row23_col10, #T_9e22a_row24_col5, #T_9e22a_row24_col10, #T_9e22a_row25_col5, #T_9e22a_row25_col10, #T_9e22a_row26_col5, #T_9e22a_row26_col10, #T_9e22a_row27_col5, #T_9e22a_row27_col10, #T_9e22a_row28_col5, #T_9e22a_row28_col10, #T_9e22a_row29_col5, #T_9e22a_row29_col10, #T_9e22a_row30_col5, #T_9e22a_row30_col10, #T_9e22a_row31_col5, #T_9e22a_row31_col10, #T_9e22a_row32_col5, #T_9e22a_row32_col10, #T_9e22a_row33_col5, #T_9e22a_row33_col10, #T_9e22a_row34_col5, #T_9e22a_row34_col10, #T_9e22a_row35_col5, #T_9e22a_row35_col10, #T_9e22a_row36_col5, #T_9e22a_row36_col10, #T_9e22a_row37_col5, #T_9e22a_row37_col10, #T_9e22a_row38_col5, #T_9e22a_row38_col10, #T_9e22a_row39_col5, #T_9e22a_row39_col10, #T_9e22a_row40_col5, #T_9e22a_row40_col10, #T_9e22a_row41_col5, #T_9e22a_row41_col10, #T_9e22a_row42_col5, #T_9e22a_row42_col10, #T_9e22a_row43_col5, #T_9e22a_row43_col10, #T_9e22a_row44_col5, #T_9e22a_row44_col10, #T_9e22a_row45_col5, #T_9e22a_row45_col10, #T_9e22a_row46_col5, #T_9e22a_row46_col10, #T_9e22a_row47_col5, #T_9e22a_row47_col10, #T_9e22a_row48_col5, #T_9e22a_row48_col10, #T_9e22a_row49_col5, #T_9e22a_row49_col10, #T_9e22a_row50_col5, #T_9e22a_row50_col10, #T_9e22a_row51_col5, #T_9e22a_row51_col10, #T_9e22a_row52_col5, #T_9e22a_row52_col10, #T_9e22a_row53_col5, #T_9e22a_row53_col10, #T_9e22a_row54_col5, #T_9e22a_row54_col10, #T_9e22a_row55_col5, #T_9e22a_row55_col10, #T_9e22a_row56_col5, #T_9e22a_row56_col10, #T_9e22a_row57_col5, #T_9e22a_row57_col10, #T_9e22a_row58_col5, #T_9e22a_row58_col10, #T_9e22a_row59_col5, #T_9e22a_row59_col10, #T_9e22a_row60_col5, #T_9e22a_row60_col10 {
#   font-weight: bold;
#   text_align: center;
# }
# #T_9e22a_row0_col8, #T_9e22a_row0_col9, #T_9e22a_row1_col8, #T_9e22a_row1_col9, #T_9e22a_row2_col8, #T_9e22a_row2_col9, #T_9e22a_row3_col8, #T_9e22a_row3_col9, #T_9e22a_row4_col8, #T_9e22a_row4_col9, #T_9e22a_row5_col8, #T_9e22a_row5_col9, #T_9e22a_row6_col8, #T_9e22a_row6_col9, #T_9e22a_row7_col8, #T_9e22a_row7_col9, #T_9e22a_row8_col8, #T_9e22a_row8_col9, #T_9e22a_row9_col8, #T_9e22a_row9_col9, #T_9e22a_row10_col8, #T_9e22a_row10_col9, #T_9e22a_row11_col8, #T_9e22a_row11_col9, #T_9e22a_row12_col8, #T_9e22a_row12_col9, #T_9e22a_row13_col8, #T_9e22a_row13_col9, #T_9e22a_row14_col8, #T_9e22a_row14_col9, #T_9e22a_row15_col8, #T_9e22a_row15_col9, #T_9e22a_row16_col8, #T_9e22a_row16_col9, #T_9e22a_row17_col8, #T_9e22a_row17_col9, #T_9e22a_row18_col8, #T_9e22a_row18_col9, #T_9e22a_row19_col8, #T_9e22a_row19_col9, #T_9e22a_row20_col8, #T_9e22a_row20_col9, #T_9e22a_row21_col8, #T_9e22a_row21_col9, #T_9e22a_row22_col8, #T_9e22a_row22_col9, #T_9e22a_row23_col8, #T_9e22a_row23_col9, #T_9e22a_row24_col8, #T_9e22a_row24_col9, #T_9e22a_row25_col8, #T_9e22a_row25_col9, #T_9e22a_row26_col8, #T_9e22a_row26_col9, #T_9e22a_row27_col8, #T_9e22a_row27_col9, #T_9e22a_row28_col8, #T_9e22a_row28_col9, #T_9e22a_row29_col8, #T_9e22a_row29_col9, #T_9e22a_row30_col8, #T_9e22a_row30_col9, #T_9e22a_row31_col8, #T_9e22a_row31_col9, #T_9e22a_row32_col8, #T_9e22a_row32_col9, #T_9e22a_row33_col8, #T_9e22a_row33_col9, #T_9e22a_row34_col8, #T_9e22a_row34_col9, #T_9e22a_row35_col8, #T_9e22a_row35_col9, #T_9e22a_row36_col8, #T_9e22a_row36_col9, #T_9e22a_row37_col8, #T_9e22a_row37_col9, #T_9e22a_row38_col8, #T_9e22a_row38_col9, #T_9e22a_row39_col8, #T_9e22a_row39_col9, #T_9e22a_row40_col8, #T_9e22a_row40_col9, #T_9e22a_row41_col8, #T_9e22a_row41_col9, #T_9e22a_row42_col8, #T_9e22a_row42_col9, #T_9e22a_row43_col8, #T_9e22a_row43_col9, #T_9e22a_row44_col8, #T_9e22a_row44_col9, #T_9e22a_row45_col8, #T_9e22a_row45_col9, #T_9e22a_row46_col8, #T_9e22a_row46_col9, #T_9e22a_row47_col8, #T_9e22a_row47_col9, #T_9e22a_row48_col8, #T_9e22a_row48_col9, #T_9e22a_row49_col8, #T_9e22a_row49_col9, #T_9e22a_row50_col8, #T_9e22a_row50_col9, #T_9e22a_row51_col8, #T_9e22a_row51_col9, #T_9e22a_row52_col8, #T_9e22a_row52_col9, #T_9e22a_row53_col8, #T_9e22a_row53_col9, #T_9e22a_row54_col8, #T_9e22a_row54_col9, #T_9e22a_row55_col8, #T_9e22a_row55_col9, #T_9e22a_row56_col8, #T_9e22a_row56_col9, #T_9e22a_row57_col8, #T_9e22a_row57_col9, #T_9e22a_row58_col8, #T_9e22a_row58_col9, #T_9e22a_row59_col8, #T_9e22a_row59_col9, #T_9e22a_row60_col8, #T_9e22a_row60_col9 {
#   font-weight: bold;
#   text_align: center;
#   text-align: center;
# }
# #T_9e22a_row10_col1, #T_9e22a_row11_col1, #T_9e22a_row12_col1, #T_9e22a_row13_col1, #T_9e22a_row14_col1, #T_9e22a_row15_col1, #T_9e22a_row16_col1, #T_9e22a_row17_col1, #T_9e22a_row18_col1, #T_9e22a_row19_col1 {
#   font-weight: bold;
#   text_align: center;
#   background-color: blue;
#   text-align: center;
# }
# #T_9e22a_row10_col2, #T_9e22a_row11_col2, #T_9e22a_row12_col2, #T_9e22a_row13_col2, #T_9e22a_row14_col2, #T_9e22a_row15_col2, #T_9e22a_row16_col2, #T_9e22a_row17_col2, #T_9e22a_row18_col2, #T_9e22a_row19_col2 {
#   font-weight: bold;
#   text_align: center;
#   background-color: rgba(0, 0, 255, 0.1);
# }
# #T_9e22a_row10_col3, #T_9e22a_row11_col3, #T_9e22a_row12_col3, #T_9e22a_row13_col3, #T_9e22a_row14_col3, #T_9e22a_row15_col3, #T_9e22a_row16_col3, #T_9e22a_row17_col3, #T_9e22a_row18_col3, #T_9e22a_row19_col3 {
#   background-color: rgba(0, 0, 255, 0.1);
# }
# #T_9e22a_row20_col1, #T_9e22a_row21_col1, #T_9e22a_row22_col1, #T_9e22a_row23_col1, #T_9e22a_row24_col1, #T_9e22a_row25_col1, #T_9e22a_row26_col1, #T_9e22a_row27_col1, #T_9e22a_row28_col1, #T_9e22a_row29_col1 {
#   font-weight: bold;
#   text_align: center;
#   background-color: green;
#   text-align: center;
# }
# #T_9e22a_row20_col2, #T_9e22a_row21_col2, #T_9e22a_row22_col2, #T_9e22a_row23_col2, #T_9e22a_row24_col2, #T_9e22a_row25_col2, #T_9e22a_row26_col2, #T_9e22a_row27_col2, #T_9e22a_row28_col2, #T_9e22a_row29_col2 {
#   font-weight: bold;
#   text_align: center;
#   background-color: rgba(0, 128, 0, 0.1);
# }
# #T_9e22a_row20_col3, #T_9e22a_row21_col3, #T_9e22a_row22_col3, #T_9e22a_row23_col3, #T_9e22a_row24_col3, #T_9e22a_row25_col3, #T_9e22a_row26_col3, #T_9e22a_row27_col3, #T_9e22a_row28_col3, #T_9e22a_row29_col3 {
#   background-color: rgba(0, 128, 0, 0.1);
# }
# #T_9e22a_row30_col1, #T_9e22a_row31_col1, #T_9e22a_row32_col1, #T_9e22a_row33_col1, #T_9e22a_row34_col1, #T_9e22a_row35_col1, #T_9e22a_row

# %%
import pandas as pd

# Exemplo de DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
    'Color': ['red', 'blue', 'green', 'yellow']
})

# Aplicando estilo e centralizando o nome das colunas
styled_df = df.style.set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])

styled_df
# Out:
# <style type="text/css">
# #T_cc55b th {
#   text-align: center;
# }
# </style>
# <table id="T_cc55b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc55b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_cc55b_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_cc55b_level0_col2" class="col_heading level0 col2" >Color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc55b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc55b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cc55b_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_cc55b_row0_col2" class="data row0 col2" >red</td>
#     </tr>
#     <tr>
#       <th id="T_cc55b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc55b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_cc55b_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_cc55b_row1_col2" class="data row1 col2" >blue</td>
#     </tr>
#     <tr>
#       <th id="T_cc55b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc55b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_cc55b_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_cc55b_row2_col2" class="data row2 col2" >green</td>
#     </tr>
#     <tr>
#       <th id="T_cc55b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc55b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_cc55b_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_cc55b_row3_col2" class="data row3 col2" >yellow</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd

# Exemplo de DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
    'Color': ['red', 'blue', 'green', 'yellow']
})

# Aplicando estilo e centralizando os valores da coluna 'A'
styled_df = df.style.set_properties(**{'text-align': 'center'}, subset=pd.IndexSlice[:, ['Color']])

styled_df
# Out:
# <style type="text/css">
# #T_d61e0_row0_col2, #T_d61e0_row1_col2, #T_d61e0_row2_col2, #T_d61e0_row3_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_d61e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d61e0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d61e0_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_d61e0_level0_col2" class="col_heading level0 col2" >Color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d61e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d61e0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d61e0_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_d61e0_row0_col2" class="data row0 col2" >red</td>
#     </tr>
#     <tr>
#       <th id="T_d61e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d61e0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d61e0_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_d61e0_row1_col2" class="data row1 col2" >blue</td>
#     </tr>
#     <tr>
#       <th id="T_d61e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d61e0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d61e0_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_d61e0_row2_col2" class="data row2 col2" >green</td>
#     </tr>
#     <tr>
#       <th id="T_d61e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d61e0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d61e0_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_d61e0_row3_col2" class="data row3 col2" >yellow</td>
#     </tr>
#   </tbody>
# </table>
